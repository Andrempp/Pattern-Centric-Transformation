# %%
import os, sys
import numpy as np

module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from packages.tcgahandler import LayerDataset

from IPython.display import display
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None  # default='warn'

DATA_DIR = "../../data/"

# %% [markdown]
# # TCGA-LGG

# %%
project = "TCGA-LGG"
layer = "mirna"
dataset = LayerDataset(DATA_DIR, project, layer)

# %%
col_types = dataset.get_types_of_columns()
head = dataset.get_layer(n_rows=5)
ids = dataset.get_layer_by_column_type("")

print(f"Number of miRNAs: {ids.shape[0]}\nNumber of patients: {col_types.most_common()[0][1]}")
print(f"Types of columns: {col_types}")
display(head)
t = dataset.get_layer()
# Out:
# Number of miRNAs: 1881
# Number of patients: 530
# Types of columns: Counter({'read_count_': 530, 'reads_per_million_miRNA_mapped_': 530, 'cross-mapped_': 530, 'miRNA_ID': 1})
#               read_count_TCGA-WY-A859-01A-12R-A36C-13  \
# miRNA_ID
# hsa-let-7a-1                                    47988
# hsa-let-7a-2                                    47732
# hsa-let-7a-3                                    48024
# hsa-let-7b                                      44799
# hsa-let-7c                                      49266
#
#               reads_per_million_miRNA_mapped_TCGA-WY-A859-01A-12R-A36C-13  \
# miRNA_ID
# hsa-let-7a-1                                          6603.1396
# hsa-let-7a-2                                          6567.9140
# hsa-let-7a-3                                          6608.0933
# hsa-let-7b                                            6164.3340
# hsa-let-7c                                            6778.9920
#
#              cross-mapped_TCGA-WY-A859-01A-12R-A36C-13  \
# miRNA_ID
# hsa-let-7a-1                                         N
# hsa-let-7a-2                                         Y
# hsa-let-7a-3                                         N
# hsa-let-7b                                           N
# hsa-let-7c                                           Y
#
#               read_count_TCGA-DB-5279-01A-03R-1762-13  \
# miRNA_ID
# hsa-let-7a-1                                   208393
# hsa-let-7a-2                                   207446
# hsa-let-7a-3                                   209405
# hsa-let-7b                                     398927
# hsa-let-7c                                     123244
#
#               reads_per_million_miRNA_mapped_TCGA-DB-5279-01A-03R-1762-13  \
# miRNA_ID
# hsa-let-7a-1                                          12768.458
# hsa-let-7a-2                                          12710.434
# hsa-let-7a-3                                          12830.464
# hsa-let-7b                                            24442.676
# hsa-let-7c                                             7551.289
#
#              cross-mapped_TCGA-DB-5279-01A-03R-1762-13  \
# miRNA_ID
# hsa-let-7a-1                                         N
# hsa-let-7a-2                                         Y
# hsa-let-7a-3                                         N
# hsa-let-7b                                           N
# hsa-let-7c                                           Y
#
#               read_count_TCGA-HT-7855-01A-11R-2401-13  \
# miRNA_ID
# hsa-let-7a-1                                    91156
# hsa-let-7a-2                                    91403
# hsa-let-7a-3                                    92288
# hsa-let-7b                                     100243
# hsa-let-7c                                      66068
#
#               reads_per_million_miRNA_mapped_TCGA-HT-7855-01A-11R-2401-13  \
# miRNA_ID
# hsa-let-7a-1                                          8017.9585
# hsa-let-7a-2                                          8039.6840
# hsa-let-7a-3                                          8117.5273
# hsa-let-7b                                            8817.2380
# hsa-let-7c                                            5811.2520
#
#              cross-mapped_TCGA-HT-7855-01A-11R-2401-13  \
# miRNA_ID
# hsa-let-7a-1                                         N
# hsa-let-7a-2                                         Y
# hsa-let-7a-3                                         N
# hsa-let-7b                                           N
# hsa-let-7c                                           Y
#
#               read_count_TCGA-DB-A64Q-01A-11R-A29V-13  ...  \
# miRNA_ID                                               ...
# hsa-let-7a-1                                    41083  ...
# hsa-let-7a-2                                    40972  ...
# hsa-let-7a-3                                    41148  ...
# hsa-let-7b                                      61183  ...
# hsa-let-7c                                      27192  ...
#
#               cross-mapped_TCGA-QH-A65V-01A-11R-A29V-13  \
# miRNA_ID
# hsa-let-7a-1                                          N
# hsa-let-7a-2                                          Y
# hsa-let-7a-3                                          N
# hsa-let-7b                                            N
# hsa-let-7c                                            Y
#
#              read_count_TCGA-P5-A5F1-01A-11R-A28I-13  \
# miRNA_ID
# hsa-let-7a-1                                   26378
# hsa-let-7a-2                                   26250
# hsa-let-7a-3                                   26557
# hsa-let-7b                                     33391
# hsa-let-7c                                     28290
#
#               reads_per_million_miRNA_mapped_TCGA-P5-A5F1-01A-11R-A28I-13  \
# miRNA_ID
# hsa-let-7a-1                                          5024.6520
# hsa-let-7a-2                                          5000.2695
# hsa-let-7a-3                                          5058.7490
# hsa-let-7b                                            6360.5330
# hsa-let-7c                                            5388.8620
#
#               cross-mapped_TCGA-P5-A5F1-01A-11R-A28I-13  \
# miRNA_ID
# hsa-let-7a-1                                          N
# hsa-let-7a-2                                          Y
# hsa-let-7a-3                                          N
# hsa-let-7b                                            N
# hsa-let-7c                                            Y
#
#              read_count_TCGA-S9-A6TY-01A-12R-A32L-13  \
# miRNA_ID
# hsa-let-7a-1                                   59026
# hsa-let-7a-2                                   59314
# hsa-let-7a-3                                   59462
# hsa-let-7b                                     80852
# hsa-let-7c                                     24036
#
#               reads_per_million_miRNA_mapped_TCGA-S9-A6TY-01A-12R-A32L-13  \
# miRNA_ID
# hsa-let-7a-1                                          5707.1597
# hsa-let-7a-2                                          5735.0060
# hsa-let-7a-3                                          5749.3160
# hsa-let-7b                                            7817.4917
# hsa-let-7c                                            2324.0146
#
#               cross-mapped_TCGA-S9-A6TY-01A-12R-A32L-13  \
# miRNA_ID
# hsa-let-7a-1                                          N
# hsa-let-7a-2                                          Y
# hsa-let-7a-3                                          N
# hsa-let-7b                                            N
# hsa-let-7c                                            Y
#
#              read_count_TCGA-R8-A6YH-01A-21R-A360-13  \
# miRNA_ID
# hsa-let-7a-1                                   90792
# hsa-let-7a-2                                   90038
# hsa-let-7a-3                                   91013
# hsa-let-7b                                    115569
# hsa-let-7c                                    131428
#
#               reads_per_million_miRNA_mapped_TCGA-R8-A6YH-01A-21R-A360-13  \
# miRNA_ID
# hsa-let-7a-1                                          11082.219
# hsa-let-7a-2                                          10990.185
# hsa-let-7a-3                                          11109.194
# hsa-let-7b                                            14106.540
# hsa-let-7c                                            16042.315
#
#               cross-mapped_TCGA-R8-A6YH-01A-21R-A360-13
# miRNA_ID
# hsa-let-7a-1                                          N
# hsa-let-7a-2                                          Y
# hsa-let-7a-3                                          N
# hsa-let-7b                                            N
# hsa-let-7c                                            Y
#
# [5 rows x 1590 columns]

# %% [markdown]
# Cross-Mapped Analysis

# %%
cross_df = dataset.get_layer_by_column_type("cross-mapped_")

tcm = pd.DataFrame(index = cross_df.index, columns = ["number of cross mappings"])
tcm["number of cross mappings"] = (cross_df == "Y").sum(axis=1)
tcm = tcm.sort_values(by="number of cross mappings", ascending = False)

cross_mapped_remove = tcm[tcm["number of cross mappings"] > 50].index

# %% [markdown]
# Check for the presence of NaNs

# %%
print(f"Are there any NaNs?\n{t.isna().any().any()}")
# Out:
# Are there any NaNs?
# False

# %% [markdown]
# Sparsity analysis - identify and remove columns with high percentage (>95) of 0s

# %%
counts_df = dataset.get_layer_by_column_type("read_count_")
print("fraction of zeros in whole dataset: ", (counts_df == 0).sum().sum() / (counts_df.shape[0]*counts_df.shape[1]))
zero_count = ((counts_df == 0).sum(axis="columns") / counts_df.shape[1])
print("\npercentage of 0s by gene:\n", zero_count.sort_values(ascending=False).head(5))

all_zero = zero_count >= 0.95
index_remove_zero = counts_df[all_zero].index
# Out:
# fraction of zeros in whole dataset:  0.6457514569729068
#
# percentage of 0s by gene:
#  miRNA_ID
# hsa-mir-7154      1.0
# hsa-mir-5186      1.0
# hsa-mir-6089-1    1.0
# hsa-mir-8052      1.0
# hsa-mir-378e      1.0
# dtype: float64

# %% [markdown]
# Process and save datasets

# %%
col_types = dataset.get_types_of_columns()
print("Types of columns:\n", list(col_types.keys()))
# Out:
# Types of columns:
#  ['miRNA_ID', 'read_count_', 'reads_per_million_miRNA_mapped_', 'cross-mapped_']

# %% [markdown]
# Raw Counts Dataset

# %%
type_of_column = "read_count_"

df = dataset.get_layer_by_column_type(type_of_column)
print(df.shape)

# drop genes with high crossmap
df = df.drop(index=cross_mapped_remove)
print(df.shape)

#drop genes with high zero quantity
df = df.drop(index=index_remove_zero)
print(df.shape)

# transpose to have samples in rows and gene in columns
df = df.T
display(df.head())

dataset.set_raw_data(data_type="counts", df=df)
# Out:
# (1881, 530)
# (1830, 530)
# (1101, 530)
# miRNA_ID                      hsa-let-7a-1  hsa-let-7a-3  hsa-let-7b  \
# TCGA-WY-A859-01A-12R-A36C-13         47988         48024       44799
# TCGA-DB-5279-01A-03R-1762-13        208393        209405      398927
# TCGA-HT-7855-01A-11R-2401-13         91156         92288      100243
# TCGA-DB-A64Q-01A-11R-A29V-13         41083         41148       61183
# TCGA-HT-7604-01A-11R-2089-13         88879         89663      163263
#
# miRNA_ID                      hsa-let-7d  hsa-let-7e  hsa-let-7f-1  \
# TCGA-WY-A859-01A-12R-A36C-13        3858       13864         26333
# TCGA-DB-5279-01A-03R-1762-13        3752        9696         63301
# TCGA-HT-7855-01A-11R-2401-13        4193       13050         16925
# TCGA-DB-A64Q-01A-11R-A29V-13        1182        2172          8377
# TCGA-HT-7604-01A-11R-2089-13        2652       10064         14298
#
# miRNA_ID                      hsa-let-7f-2  hsa-let-7g  hsa-let-7i  \
# TCGA-WY-A859-01A-12R-A36C-13         27072        5127        2328
# TCGA-DB-5279-01A-03R-1762-13         64044        4786        4682
# TCGA-HT-7855-01A-11R-2401-13         17241        5284        2962
# TCGA-DB-A64Q-01A-11R-A29V-13          8653        1120        1625
# TCGA-HT-7604-01A-11R-2089-13         14304        3203        2138
#
# miRNA_ID                      hsa-mir-1-1  ...  hsa-mir-937  hsa-mir-939  \
# TCGA-WY-A859-01A-12R-A36C-13           73  ...            3            2
# TCGA-DB-5279-01A-03R-1762-13           25  ...           20            4
# TCGA-HT-7855-01A-11R-2401-13            5  ...           14            3
# TCGA-DB-A64Q-01A-11R-A29V-13            7  ...           15            0
# TCGA-HT-7604-01A-11R-2089-13            0  ...           28            5
#
# miRNA_ID                      hsa-mir-940  hsa-mir-942  hsa-mir-943  \
# TCGA-WY-A859-01A-12R-A36C-13           63            7            0
# TCGA-DB-5279-01A-03R-1762-13          105           34            6
# TCGA-HT-7855-01A-11R-2401-13           19           10            0
# TCGA-DB-A64Q-01A-11R-A29V-13            2            1            0
# TCGA-HT-7604-01A-11R-2089-13           30            4            0
#
# miRNA_ID                      hsa-mir-944  hsa-mir-95  hsa-mir-96  hsa-mir-98  \
# TCGA-WY-A859-01A-12R-A36C-13            0         138         101         963
# TCGA-DB-5279-01A-03R-1762-13            2          73         122         974
# TCGA-HT-7855-01A-11R-2401-13            0          28          40         421
# TCGA-DB-A64Q-01A-11R-A29V-13            0          22          87         234
# TCGA-HT-7604-01A-11R-2089-13            0          43         121         410
#
# miRNA_ID                      hsa-mir-99b
# TCGA-WY-A859-01A-12R-A36C-13       157711
# TCGA-DB-5279-01A-03R-1762-13       208684
# TCGA-HT-7855-01A-11R-2401-13       261817
# TCGA-DB-A64Q-01A-11R-A29V-13        42247
# TCGA-HT-7604-01A-11R-2089-13       212061
#
# [5 rows x 1101 columns]

# %% [markdown]
# Reads Per Million (RPM) Dataset

# %%
type_of_column = "reads_per_million_miRNA_mapped_"

df = dataset.get_layer_by_column_type(type_of_column)
print(df.shape)

# drop genes with high crossmap
df = df.drop(index=cross_mapped_remove)
print(df.shape)

#drop genes with all zeros
df = df.drop(index=index_remove_zero)
print(df.shape)

# transpose to have samples in rows and gene in columns
df = df.T
display(df.head())

dataset.set_raw_data(data_type="rpm", df=df)
# Out:
# (1881, 530)
# (1830, 530)
# (1101, 530)
# miRNA_ID                      hsa-let-7a-1  hsa-let-7a-3  hsa-let-7b  \
# TCGA-WY-A859-01A-12R-A36C-13     6603.1396     6608.0933    6164.334
# TCGA-DB-5279-01A-03R-1762-13    12768.4580    12830.4640   24442.676
# TCGA-HT-7855-01A-11R-2401-13     8017.9585     8117.5273    8817.238
# TCGA-DB-A64Q-01A-11R-A29V-13     5334.9450     5343.3853    7945.085
# TCGA-HT-7604-01A-11R-2089-13    13372.6350    13490.5950   24564.370
#
# miRNA_ID                      hsa-let-7d  hsa-let-7e  hsa-let-7f-1  \
# TCGA-WY-A859-01A-12R-A36C-13   530.86005  1907.68370     3623.4158
# TCGA-DB-5279-01A-03R-1762-13   229.88898   594.08410     3878.5186
# TCGA-HT-7855-01A-11R-2401-13   368.81060  1147.86040     1488.7001
# TCGA-DB-A64Q-01A-11R-A29V-13   153.49182   282.05096     1087.8181
# TCGA-HT-7604-01A-11R-2089-13   399.01697  1514.21830     2151.2612
#
# miRNA_ID                      hsa-let-7f-2  hsa-let-7g  hsa-let-7i  \
# TCGA-WY-A859-01A-12R-A36C-13     3725.1020   705.47424   320.33237
# TCGA-DB-5279-01A-03R-1762-13     3924.0430   293.24323   286.87106
# TCGA-HT-7855-01A-11R-2401-13     1516.4950   464.77350   260.53350
# TCGA-DB-A64Q-01A-11R-A29V-13     1123.6588   145.44064   211.01878
# TCGA-HT-7604-01A-11R-2089-13     2152.1638   481.91980   321.68110
#
# miRNA_ID                      hsa-mir-1-1  ...  hsa-mir-937  hsa-mir-939  \
# TCGA-WY-A859-01A-12R-A36C-13    10.044786  ...     0.412799     0.275200
# TCGA-DB-5279-01A-03R-1762-13     1.531776  ...     1.225421     0.245084
# TCGA-HT-7855-01A-11R-2401-13     0.439793  ...     1.231421     0.263876
# TCGA-DB-A64Q-01A-11R-A29V-13     0.909004  ...     1.947866     0.000000
# TCGA-HT-7604-01A-11R-2089-13     0.000000  ...     4.212849     0.752294
#
# miRNA_ID                      hsa-mir-940  hsa-mir-942  hsa-mir-943  \
# TCGA-WY-A859-01A-12R-A36C-13     8.668788     0.963199     0.000000
# TCGA-DB-5279-01A-03R-1762-13     6.433460     2.083216     0.367626
# TCGA-HT-7855-01A-11R-2401-13     1.671214     0.879586     0.000000
# TCGA-DB-A64Q-01A-11R-A29V-13     0.259715     0.129858     0.000000
# TCGA-HT-7604-01A-11R-2089-13     4.513767     0.601836     0.000000
#
# miRNA_ID                      hsa-mir-944  hsa-mir-95  hsa-mir-96  hsa-mir-98  \
# TCGA-WY-A859-01A-12R-A36C-13     0.000000   18.988773   13.897581  132.508620
# TCGA-DB-5279-01A-03R-1762-13     0.122542    4.472787    7.475068   59.678000
# TCGA-HT-7855-01A-11R-2401-13     0.000000    2.462842    3.518346   37.030590
# TCGA-DB-A64Q-01A-11R-A29V-13     0.000000    2.856870   11.297621   30.386705
# TCGA-HT-7604-01A-11R-2089-13     0.000000    6.469732   18.205524   61.688145
#
# miRNA_ID                      hsa-mir-99b
# TCGA-WY-A859-01A-12R-A36C-13    21701.004
# TCGA-DB-5279-01A-03R-1762-13    12786.287
# TCGA-HT-7855-01A-11R-2401-13    23029.068
# TCGA-DB-A64Q-01A-11R-A29V-13     5486.099
# TCGA-HT-7604-01A-11R-2089-13    31906.460
#
# [5 rows x 1101 columns]

# %% [markdown]
# # TCGA-COAD

# %%
project = "TCGA-COAD"
layer = "mirna"
dataset = LayerDataset(DATA_DIR, project, layer)

# %%
col_types = dataset.get_types_of_columns()
head = dataset.get_layer(n_rows=5)
ids = dataset.get_layer_by_column_type("")

print(f"Number of miRNAs: {ids.shape[0]}\nNumber of patients: {col_types.most_common()[0][1]}")
print(f"Types of columns: {col_types}")
display(head)
t = dataset.get_layer()
# Out:
# Number of miRNAs: 1881
# Number of patients: 465
# Types of columns: Counter({'read_count_': 465, 'reads_per_million_miRNA_mapped_': 465, 'cross-mapped_': 465, 'miRNA_ID': 1})
#               read_count_TCGA-A6-6141-01A-11H-1773-13  \
# miRNA_ID
# hsa-let-7a-1                                    42021
# hsa-let-7a-2                                    41969
# hsa-let-7a-3                                    41950
# hsa-let-7b                                      53873
# hsa-let-7c                                       7408
#
#               reads_per_million_miRNA_mapped_TCGA-A6-6141-01A-11H-1773-13  \
# miRNA_ID
# hsa-let-7a-1                                          8316.6620
# hsa-let-7a-2                                          8306.3700
# hsa-let-7a-3                                          8302.6100
# hsa-let-7b                                           10662.3720
# hsa-let-7c                                            1466.1677
#
#              cross-mapped_TCGA-A6-6141-01A-11H-1773-13  \
# miRNA_ID
# hsa-let-7a-1                                         N
# hsa-let-7a-2                                         Y
# hsa-let-7a-3                                         N
# hsa-let-7b                                           N
# hsa-let-7c                                           Y
#
#               read_count_TCGA-CM-6678-01A-11H-1838-13  \
# miRNA_ID
# hsa-let-7a-1                                    42764
# hsa-let-7a-2                                    42359
# hsa-let-7a-3                                    42462
# hsa-let-7b                                      43892
# hsa-let-7c                                       2701
#
#               reads_per_million_miRNA_mapped_TCGA-CM-6678-01A-11H-1838-13  \
# miRNA_ID
# hsa-let-7a-1                                         8307.48500
# hsa-let-7a-2                                         8228.80900
# hsa-let-7a-3                                         8248.81700
# hsa-let-7b                                           8526.61400
# hsa-let-7c                                            524.70575
#
#              cross-mapped_TCGA-CM-6678-01A-11H-1838-13  \
# miRNA_ID
# hsa-let-7a-1                                         N
# hsa-let-7a-2                                         N
# hsa-let-7a-3                                         N
# hsa-let-7b                                           N
# hsa-let-7c                                           N
#
#               read_count_TCGA-D5-6922-01A-11H-1927-13  \
# miRNA_ID
# hsa-let-7a-1                                    54512
# hsa-let-7a-2                                    54342
# hsa-let-7a-3                                    54331
# hsa-let-7b                                      49460
# hsa-let-7c                                       5093
#
#               reads_per_million_miRNA_mapped_TCGA-D5-6922-01A-11H-1927-13  \
# miRNA_ID
# hsa-let-7a-1                                          8824.2760
# hsa-let-7a-2                                          8796.7570
# hsa-let-7a-3                                          8794.9770
# hsa-let-7b                                            8006.4697
# hsa-let-7c                                             824.4430
#
#              cross-mapped_TCGA-D5-6922-01A-11H-1927-13  \
# miRNA_ID
# hsa-let-7a-1                                         N
# hsa-let-7a-2                                         Y
# hsa-let-7a-3                                         N
# hsa-let-7b                                           N
# hsa-let-7c                                           Y
#
#               read_count_TCGA-CM-5341-01A-01T-1409-13  ...  \
# miRNA_ID                                               ...
# hsa-let-7a-1                                    26848  ...
# hsa-let-7a-2                                    26558  ...
# hsa-let-7a-3                                    27098  ...
# hsa-let-7b                                      39949  ...
# hsa-let-7c                                       2603  ...
#
#               cross-mapped_TCGA-A6-6649-01A-11H-1773-13  \
# miRNA_ID
# hsa-let-7a-1                                          N
# hsa-let-7a-2                                          Y
# hsa-let-7a-3                                          N
# hsa-let-7b                                            N
# hsa-let-7c                                            Y
#
#              read_count_TCGA-AA-3494-01A-01T-1409-13  \
# miRNA_ID
# hsa-let-7a-1                                    9169
# hsa-let-7a-2                                    9203
# hsa-let-7a-3                                    9314
# hsa-let-7b                                     14815
# hsa-let-7c                                       279
#
#               reads_per_million_miRNA_mapped_TCGA-AA-3494-01A-01T-1409-13  \
# miRNA_ID
# hsa-let-7a-1                                         5031.58640
# hsa-let-7a-2                                         5050.24460
# hsa-let-7a-3                                         5111.15670
# hsa-let-7b                                           8129.88960
# hsa-let-7c                                            153.10423
#
#               cross-mapped_TCGA-AA-3494-01A-01T-1409-13  \
# miRNA_ID
# hsa-let-7a-1                                          N
# hsa-let-7a-2                                          N
# hsa-let-7a-3                                          N
# hsa-let-7b                                            N
# hsa-let-7c                                            N
#
#              read_count_TCGA-5M-AATA-01A-31H-A41D-13  \
# miRNA_ID
# hsa-let-7a-1                                   18795
# hsa-let-7a-2                                   18469
# hsa-let-7a-3                                   18927
# hsa-let-7b                                     23221
# hsa-let-7c                                      1074
#
#               reads_per_million_miRNA_mapped_TCGA-5M-AATA-01A-31H-A41D-13  \
# miRNA_ID
# hsa-let-7a-1                                          6052.1440
# hsa-let-7a-2                                          5947.1694
# hsa-let-7a-3                                          6094.6490
# hsa-let-7b                                            7477.3525
# hsa-let-7c                                             345.8368
#
#               cross-mapped_TCGA-5M-AATA-01A-31H-A41D-13  \
# miRNA_ID
# hsa-let-7a-1                                          N
# hsa-let-7a-2                                          N
# hsa-let-7a-3                                          N
# hsa-let-7b                                            N
# hsa-let-7c                                            N
#
#              read_count_TCGA-5M-AAT5-01A-21H-A41D-13  \
# miRNA_ID
# hsa-let-7a-1                                   12225
# hsa-let-7a-2                                   12239
# hsa-let-7a-3                                   12406
# hsa-let-7b                                     11576
# hsa-let-7c                                       516
#
#               reads_per_million_miRNA_mapped_TCGA-5M-AAT5-01A-21H-A41D-13  \
# miRNA_ID
# hsa-let-7a-1                                          5043.9473
# hsa-let-7a-2                                          5049.7236
# hsa-let-7a-3                                          5118.6265
# hsa-let-7b                                            4776.1750
# hsa-let-7c                                             212.8979
#
#               cross-mapped_TCGA-5M-AAT5-01A-21H-A41D-13
# miRNA_ID
# hsa-let-7a-1                                          N
# hsa-let-7a-2                                          N
# hsa-let-7a-3                                          N
# hsa-let-7b                                            N
# hsa-let-7c                                            N
#
# [5 rows x 1395 columns]

# %% [markdown]
# Cross-Mapped Analysis

# %%
cross_df = dataset.get_layer_by_column_type("cross-mapped_")

tcm = pd.DataFrame(index = cross_df.index, columns = ["number of cross mappings"])
tcm["number of cross mappings"] = (cross_df == "Y").sum(axis=1)
tcm = tcm.sort_values(by="number of cross mappings", ascending = False)

cross_mapped_remove = tcm[tcm["number of cross mappings"] > 50].index

# %% [markdown]
# Check for the presence of NaNs

# %%
print(f"Are there any NaNs?\n{t.isna().any().any()}")
# Out:
# Are there any NaNs?
# False

# %% [markdown]
# Sparsity analysis - identify and remove columns with high percentage (>95) of 0s

# %%
counts_df = dataset.get_layer_by_column_type("read_count_")
print("fraction of zeros in whole dataset: ", (counts_df == 0).sum().sum() / (counts_df.shape[0]*counts_df.shape[1]))
zero_count = ((counts_df == 0).sum(axis="columns") / counts_df.shape[1])
print("\npercentage of 0s by gene:\n", zero_count.sort_values(ascending=False).head(5))

all_zero = zero_count >= 0.95
index_remove_zero = counts_df[all_zero].index
# Out:
# fraction of zeros in whole dataset:  0.6905180840664712
#
# percentage of 0s by gene:
#  miRNA_ID
# hsa-mir-4500    1.0
# hsa-mir-8057    1.0
# hsa-mir-8053    1.0
# hsa-mir-8054    1.0
# hsa-mir-4255    1.0
# dtype: float64

# %% [markdown]
# Process and save datasets

# %%
col_types = dataset.get_types_of_columns()
print("Types of columns:\n", list(col_types.keys()))
# Out:
# Types of columns:
#  ['miRNA_ID', 'read_count_', 'reads_per_million_miRNA_mapped_', 'cross-mapped_']

# %% [markdown]
# Raw Counts Dataset

# %%
type_of_column = "read_count_"

df = dataset.get_layer_by_column_type(type_of_column)
print(df.shape)

# drop genes with high crossmap
df = df.drop(index=cross_mapped_remove)
print(df.shape)

#drop genes with high zero quantity
df = df.drop(index=index_remove_zero)
print(df.shape)

# transpose to have samples in rows and gene in columns
df = df.T
display(df.head())

dataset.set_raw_data(data_type="counts", df=df)
# Out:
# (1881, 465)
# (1833, 465)
# (1061, 465)
# miRNA_ID                      hsa-let-7a-1  hsa-let-7a-3  hsa-let-7b  \
# TCGA-A6-6141-01A-11H-1773-13         42021         41950       53873
# TCGA-CM-6678-01A-11H-1838-13         42764         42462       43892
# TCGA-D5-6922-01A-11H-1927-13         54512         54331       49460
# TCGA-CM-5341-01A-01T-1409-13         26848         27098       39949
# TCGA-DM-A0X9-01A-11H-A154-13         27128         26995       19479
#
# miRNA_ID                      hsa-let-7d  hsa-let-7e  hsa-let-7f-1  \
# TCGA-A6-6141-01A-11H-1773-13        4111        3866         25845
# TCGA-CM-6678-01A-11H-1838-13        1713        5150         43202
# TCGA-D5-6922-01A-11H-1927-13        2933        8286         32702
# TCGA-CM-5341-01A-01T-1409-13        1758        1285         10873
# TCGA-DM-A0X9-01A-11H-A154-13        2305        1393         21524
#
# miRNA_ID                      hsa-let-7f-2  hsa-let-7g  hsa-let-7i  \
# TCGA-A6-6141-01A-11H-1773-13         26164        4861        3546
# TCGA-CM-6678-01A-11H-1838-13         43482        3632        2190
# TCGA-D5-6922-01A-11H-1927-13         33070        2904        1242
# TCGA-CM-5341-01A-01T-1409-13         11075        1937        1912
# TCGA-DM-A0X9-01A-11H-A154-13         21718        3205        1211
#
# miRNA_ID                      hsa-mir-1-1  ...  hsa-mir-938  hsa-mir-939  \
# TCGA-A6-6141-01A-11H-1773-13           94  ...            0           10
# TCGA-CM-6678-01A-11H-1838-13          142  ...            0            6
# TCGA-D5-6922-01A-11H-1927-13          413  ...            0           10
# TCGA-CM-5341-01A-01T-1409-13           15  ...            0            4
# TCGA-DM-A0X9-01A-11H-A154-13           44  ...            0            6
#
# miRNA_ID                      hsa-mir-940  hsa-mir-942  hsa-mir-943  \
# TCGA-A6-6141-01A-11H-1773-13           29           46            0
# TCGA-CM-6678-01A-11H-1838-13           12           27            0
# TCGA-D5-6922-01A-11H-1927-13            8           84            0
# TCGA-CM-5341-01A-01T-1409-13            3           12            0
# TCGA-DM-A0X9-01A-11H-A154-13           15           95            0
#
# miRNA_ID                      hsa-mir-944  hsa-mir-95  hsa-mir-96  hsa-mir-98  \
# TCGA-A6-6141-01A-11H-1773-13            4          64          89         260
# TCGA-CM-6678-01A-11H-1838-13            2         102         127         271
# TCGA-D5-6922-01A-11H-1927-13            1          51          43         183
# TCGA-CM-5341-01A-01T-1409-13            0          52          61         223
# TCGA-DM-A0X9-01A-11H-A154-13            0          68          48         229
#
# miRNA_ID                      hsa-mir-99b
# TCGA-A6-6141-01A-11H-1773-13        69395
# TCGA-CM-6678-01A-11H-1838-13        60982
# TCGA-D5-6922-01A-11H-1927-13        77394
# TCGA-CM-5341-01A-01T-1409-13        42602
# TCGA-DM-A0X9-01A-11H-A154-13        30600
#
# [5 rows x 1061 columns]

# %% [markdown]
# Reads Per Million (RPM) Dataset

# %%
type_of_column = "reads_per_million_miRNA_mapped_"

df = dataset.get_layer_by_column_type(type_of_column)
print(df.shape)

# drop genes with high crossmap
df = df.drop(index=cross_mapped_remove)
print(df.shape)

#drop genes with all zeros
df = df.drop(index=index_remove_zero)
print(df.shape)

# transpose to have samples in rows and gene in columns
df = df.T
display(df.head())

dataset.set_raw_data(data_type="rpm", df=df)
# Out:
# (1881, 465)
# (1833, 465)
# (1061, 465)
# miRNA_ID                      hsa-let-7a-1  hsa-let-7a-3  hsa-let-7b  \
# TCGA-A6-6141-01A-11H-1773-13      8316.662      8302.610  10662.3720
# TCGA-CM-6678-01A-11H-1838-13      8307.485      8248.817   8526.6140
# TCGA-D5-6922-01A-11H-1927-13      8824.276      8794.977   8006.4697
# TCGA-CM-5341-01A-01T-1409-13      8310.050      8387.430  12365.0990
# TCGA-DM-A0X9-01A-11H-A154-13      8591.553      8549.432   6169.0820
#
# miRNA_ID                      hsa-let-7d  hsa-let-7e  hsa-let-7f-1  \
# TCGA-A6-6141-01A-11H-1773-13   813.63600   765.14636     5115.1597
# TCGA-CM-6678-01A-11H-1838-13   332.77340  1000.45710     8392.5720
# TCGA-D5-6922-01A-11H-1927-13   474.78723  1341.31850     5293.7236
# TCGA-CM-5341-01A-01T-1409-13   544.13990   397.73590     3365.4338
# TCGA-DM-A0X9-01A-11H-A154-13   730.00330   441.16900     6816.7420
#
# miRNA_ID                      hsa-let-7f-2  hsa-let-7g  hsa-let-7i  \
# TCGA-A6-6141-01A-11H-1773-13     5178.2954   962.07360   701.81300
# TCGA-CM-6678-01A-11H-1838-13     8446.9660   705.56506   425.43710
# TCGA-D5-6922-01A-11H-1927-13     5353.2950   470.09277   201.05208
# TCGA-CM-5341-01A-01T-1409-13     3427.9573   599.54430   591.80630
# TCGA-DM-A0X9-01A-11H-A154-13     6878.1830  1015.03710   383.52884
#
# miRNA_ID                      hsa-mir-1-1  ...  hsa-mir-938  hsa-mir-939  \
# TCGA-A6-6141-01A-11H-1773-13    18.604180  ...          0.0     1.979168
# TCGA-CM-6678-01A-11H-1838-13    27.585419  ...          0.0     1.165581
# TCGA-D5-6922-01A-11H-1927-13    66.855484  ...          0.0     1.618777
# TCGA-CM-5341-01A-01T-1409-13     4.642832  ...          0.0     1.238088
# TCGA-DM-A0X9-01A-11H-A154-13    13.934987  ...          0.0     1.900225
#
# miRNA_ID                      hsa-mir-940  hsa-mir-942  hsa-mir-943  \
# TCGA-A6-6141-01A-11H-1773-13     5.739587     9.104173          0.0
# TCGA-CM-6678-01A-11H-1838-13     2.331162     5.245115          0.0
# TCGA-D5-6922-01A-11H-1927-13     1.295021    13.597725          0.0
# TCGA-CM-5341-01A-01T-1409-13     0.928566     3.714265          0.0
# TCGA-DM-A0X9-01A-11H-A154-13     4.750564    30.086905          0.0
#
# miRNA_ID                      hsa-mir-944  hsa-mir-95  hsa-mir-96  hsa-mir-98  \
# TCGA-A6-6141-01A-11H-1773-13     0.791667   12.666676   17.614595   51.458370
# TCGA-CM-6678-01A-11H-1838-13     0.388527   19.814878   24.671467   52.645412
# TCGA-D5-6922-01A-11H-1927-13     0.161878    8.255762    6.960740   29.623615
# TCGA-CM-5341-01A-01T-1409-13     0.000000   16.095150   18.880850   69.023430
# TCGA-DM-A0X9-01A-11H-A154-13     0.000000   21.535889   15.201804   72.525276
#
# miRNA_ID                      hsa-mir-99b
# TCGA-A6-6141-01A-11H-1773-13    13734.437
# TCGA-CM-6678-01A-11H-1838-13    11846.578
# TCGA-D5-6922-01A-11H-1927-13    12528.361
# TCGA-CM-5341-01A-01T-1409-13    13186.261
# TCGA-DM-A0X9-01A-11H-A154-13     9691.150
#
# [5 rows x 1061 columns]
