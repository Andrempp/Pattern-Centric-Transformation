# %%
import os, sys
import numpy as np

module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from packages.tcgahandler import LayerDataset

import re
import math
from IPython.display import display
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None  # default='warn'

DATA_DIR = "../../data/"
layer = "mrna"

# %% [markdown]
# # TCGA-LGG

# %%
project = "TCGA-LGG"
dataset = LayerDataset(DATA_DIR, project, layer)

# %%
col_types = dataset.get_types_of_columns()
head = dataset.get_layer(n_rows=5)
ids = dataset.get_layer_by_column_type("")

print(f"Number of miRNAs: {ids.shape[0]}\nNumber of patients: {col_types.most_common()[0][1]}")
print(f"Types of columns: {col_types}")
display(head)
# Out:
# Number of miRNAs: 60664
# Number of patients: 534
# Types of columns: Counter({'unstranded_': 534, 'stranded_first_': 534, 'stranded_second_': 534, 'tpm_unstranded_': 534, 'fpkm_unstranded_': 534, 'fpkm_uq_unstranded_': 534, 'gene_id': 1, 'gene_name': 1, 'gene_type': 1})
#                    gene_name       gene_type  \
# gene_id
# ENSG00000000003.15    TSPAN6  protein_coding
# ENSG00000000005.6       TNMD  protein_coding
# ENSG00000000419.13      DPM1  protein_coding
# ENSG00000000457.14     SCYL3  protein_coding
# ENSG00000000460.17  C1orf112  protein_coding
#
#                     unstranded_TCGA-WY-A859-01A-12R-A36H-07  \
# gene_id
# ENSG00000000003.15                                     2884
# ENSG00000000005.6                                        12
# ENSG00000000419.13                                     1489
# ENSG00000000457.14                                      634
# ENSG00000000460.17                                      214
#
#                     unstranded_TCGA-QH-A86X-01A-11R-A36H-07  \
# gene_id
# ENSG00000000003.15                                     4390
# ENSG00000000005.6                                        14
# ENSG00000000419.13                                     1472
# ENSG00000000457.14                                      886
# ENSG00000000460.17                                      223
#
#                     unstranded_TCGA-DU-6402-01A-11R-1708-07  \
# gene_id
# ENSG00000000003.15                                     4926
# ENSG00000000005.6                                         4
# ENSG00000000419.13                                     1435
# ENSG00000000457.14                                      474
# ENSG00000000460.17                                      347
#
#                     unstranded_TCGA-HT-7611-01A-11R-2403-07  \
# gene_id
# ENSG00000000003.15                                     6025
# ENSG00000000005.6                                         8
# ENSG00000000419.13                                     1272
# ENSG00000000457.14                                      789
# ENSG00000000460.17                                      321
#
#                     unstranded_TCGA-DB-A4XA-01A-11R-A26U-07  \
# gene_id
# ENSG00000000003.15                                     1764
# ENSG00000000005.6                                         5
# ENSG00000000419.13                                      739
# ENSG00000000457.14                                      379
# ENSG00000000460.17                                       96
#
#                     unstranded_TCGA-P5-A5EY-01A-11R-A27Q-07  \
# gene_id
# ENSG00000000003.15                                     2377
# ENSG00000000005.6                                         8
# ENSG00000000419.13                                      649
# ENSG00000000457.14                                      331
# ENSG00000000460.17                                       79
#
#                     unstranded_TCGA-HW-8320-01A-11R-2404-07  \
# gene_id
# ENSG00000000003.15                                     4267
# ENSG00000000005.6                                         1
# ENSG00000000419.13                                     1200
# ENSG00000000457.14                                      786
# ENSG00000000460.17                                      332
#
#                     unstranded_TCGA-DU-6392-01A-11R-1708-07  ...  \
# gene_id                                                      ...
# ENSG00000000003.15                                     3274  ...
# ENSG00000000005.6                                         3  ...
# ENSG00000000419.13                                      811  ...
# ENSG00000000457.14                                     1051  ...
# ENSG00000000460.17                                      326  ...
#
#                     unstranded_TCGA-S9-A7J1-01A-21R-A34R-07  \
# gene_id
# ENSG00000000003.15                                     2623
# ENSG00000000005.6                                         5
# ENSG00000000419.13                                      708
# ENSG00000000457.14                                      567
# ENSG00000000460.17                                      154
#
#                     unstranded_TCGA-S9-A7J2-01A-11R-A34F-07  \
# gene_id
# ENSG00000000003.15                                     3236
# ENSG00000000005.6                                        15
# ENSG00000000419.13                                      976
# ENSG00000000457.14                                      602
# ENSG00000000460.17                                      184
#
#                     unstranded_TCGA-S9-A89Z-01A-11R-A36H-07  \
# gene_id
# ENSG00000000003.15                                     3505
# ENSG00000000005.6                                         4
# ENSG00000000419.13                                     1052
# ENSG00000000457.14                                      390
# ENSG00000000460.17                                      218
#
#                     unstranded_TCGA-TM-A7CF-01A-11R-A32Q-07  \
# gene_id
# ENSG00000000003.15                                     1695
# ENSG00000000005.6                                         6
# ENSG00000000419.13                                      714
# ENSG00000000457.14                                      369
# ENSG00000000460.17                                       96
#
#                     unstranded_TCGA-TM-A7CF-02A-11R-A32Q-07  \
# gene_id
# ENSG00000000003.15                                     2153
# ENSG00000000005.6                                        11
# ENSG00000000419.13                                      846
# ENSG00000000457.14                                      431
# ENSG00000000460.17                                      183
#
#                     unstranded_TCGA-TM-A84B-01A-11R-A36H-07  \
# gene_id
# ENSG00000000003.15                                     7529
# ENSG00000000005.6                                         4
# ENSG00000000419.13                                     1356
# ENSG00000000457.14                                      833
# ENSG00000000460.17                                      542
#
#                     unstranded_TCGA-TQ-A7RP-01A-21R-A34F-07  \
# gene_id
# ENSG00000000003.15                                     1801
# ENSG00000000005.6                                        11
# ENSG00000000419.13                                     1134
# ENSG00000000457.14                                      515
# ENSG00000000460.17                                      191
#
#                     unstranded_TCGA-VM-A8CD-01A-11R-A36H-07  \
# gene_id
# ENSG00000000003.15                                     2041
# ENSG00000000005.6                                         3
# ENSG00000000419.13                                     1274
# ENSG00000000457.14                                      622
# ENSG00000000460.17                                      219
#
#                     unstranded_TCGA-WY-A85A-01A-21R-A36H-07  \
# gene_id
# ENSG00000000003.15                                     2412
# ENSG00000000005.6                                         3
# ENSG00000000419.13                                      758
# ENSG00000000457.14                                      515
# ENSG00000000460.17                                      186
#
#                     unstranded_TCGA-WY-A85C-01A-11R-A36H-07
# gene_id
# ENSG00000000003.15                                     4629
# ENSG00000000005.6                                        17
# ENSG00000000419.13                                     1174
# ENSG00000000457.14                                      733
# ENSG00000000460.17                                      229
#
# [5 rows x 3206 columns]

# %% [markdown]
# Check for the presence of NaNs

# %%
t = dataset.get_layer_by_column_type('unstranded_')
t = t.drop(columns=["gene_name", "gene_type"])
print(f"Are there any NaNs?\n{t.isna().any().any()}")
# Out:
# Are there any NaNs?
# False

# %% [markdown]
# Sparsity analysis - identify and remove columns with high percentage (>95) of 0s

# %%
print("fraction of zeros in whole dataset: ", (t == 0).sum().sum() / (t.shape[0]*t.shape[1]))
zero_count = ((t == 0).sum(axis="columns") / t.shape[1])
print(zero_count.sort_values(ascending=False).head(5))
all_zero = zero_count == 1
index_remove_zero = t[all_zero].index
# Out:
# fraction of zeros in whole dataset:  0.44243088719543666
# gene_id
# ENSG00000199744.1          1.0
# ENSG00000277108.1          1.0
# ENSG00000235521.1          1.0
# ENSG00000277119.1          1.0
# ENSG00000277120.5_PAR_Y    1.0
# dtype: float64

# %% [markdown]
# Process and save datasets

# %%
col_types = dataset.get_types_of_columns()
print("Types of columns:\n", list(col_types.keys()))
# Out:
# Types of columns:
#  ['gene_id', 'gene_name', 'gene_type', 'unstranded_', 'stranded_first_', 'stranded_second_', 'tpm_unstranded_', 'fpkm_unstranded_', 'fpkm_uq_unstranded_']

# %% [markdown]
# Raw Counts Dataset

# %%
type_of_column = "unstranded_"

df = dataset.get_layer_by_column_type(type_of_column)
print(df.shape)

# drop last 4 rows with NaN values
df = df.dropna()
print(df.shape)

# drop columns gene_name and gene_type
df = df.drop(columns = ["gene_name", "gene_type"])
print(df.shape)

# drop genes with all zeros
df = df.drop(index=index_remove_zero)
print(df.shape)

# transpose dataframe
df = df.T

display(df.head())
dataset.set_raw_data(data_type="counts", df=df)
# Out:
# (60664, 536)
# (60660, 536)
# (60660, 534)
# (57582, 534)
# gene_id                       ENSG00000000003.15  ENSG00000000005.6  \
# TCGA-WY-A859-01A-12R-A36H-07                2884                 12
# TCGA-QH-A86X-01A-11R-A36H-07                4390                 14
# TCGA-DU-6402-01A-11R-1708-07                4926                  4
# TCGA-HT-7611-01A-11R-2403-07                6025                  8
# TCGA-DB-A4XA-01A-11R-A26U-07                1764                  5
#
# gene_id                       ENSG00000000419.13  ENSG00000000457.14  \
# TCGA-WY-A859-01A-12R-A36H-07                1489                 634
# TCGA-QH-A86X-01A-11R-A36H-07                1472                 886
# TCGA-DU-6402-01A-11R-1708-07                1435                 474
# TCGA-HT-7611-01A-11R-2403-07                1272                 789
# TCGA-DB-A4XA-01A-11R-A26U-07                 739                 379
#
# gene_id                       ENSG00000000460.17  ENSG00000000938.13  \
# TCGA-WY-A859-01A-12R-A36H-07                 214                 301
# TCGA-QH-A86X-01A-11R-A36H-07                 223                 539
# TCGA-DU-6402-01A-11R-1708-07                 347                1093
# TCGA-HT-7611-01A-11R-2403-07                 321                 262
# TCGA-DB-A4XA-01A-11R-A26U-07                  96                 468
#
# gene_id                       ENSG00000000971.16  ENSG00000001036.14  \
# TCGA-WY-A859-01A-12R-A36H-07                 277                 411
# TCGA-QH-A86X-01A-11R-A36H-07                 379                1067
# TCGA-DU-6402-01A-11R-1708-07                2941                4823
# TCGA-HT-7611-01A-11R-2403-07                 513                 342
# TCGA-DB-A4XA-01A-11R-A26U-07                 300                 371
#
# gene_id                       ENSG00000001084.13  ENSG00000001167.14  ...  \
# TCGA-WY-A859-01A-12R-A36H-07                3686                1331  ...
# TCGA-QH-A86X-01A-11R-A36H-07                8869                3116  ...
# TCGA-DU-6402-01A-11R-1708-07                3108                1251  ...
# TCGA-HT-7611-01A-11R-2403-07                7912                2051  ...
# TCGA-DB-A4XA-01A-11R-A26U-07                1376                1184  ...
#
# gene_id                       ENSG00000288658.1  ENSG00000288659.1  \
# TCGA-WY-A859-01A-12R-A36H-07                383                  2
# TCGA-QH-A86X-01A-11R-A36H-07                 37                  0
# TCGA-DU-6402-01A-11R-1708-07                  6                  0
# TCGA-HT-7611-01A-11R-2403-07                 17                  0
# TCGA-DB-A4XA-01A-11R-A26U-07                 21                  0
#
# gene_id                       ENSG00000288660.1  ENSG00000288662.1  \
# TCGA-WY-A859-01A-12R-A36H-07                  1                  0
# TCGA-QH-A86X-01A-11R-A36H-07                  1                  1
# TCGA-DU-6402-01A-11R-1708-07                  0                  0
# TCGA-HT-7611-01A-11R-2403-07                  0                  0
# TCGA-DB-A4XA-01A-11R-A26U-07                  0                  0
#
# gene_id                       ENSG00000288663.1  ENSG00000288667.1  \
# TCGA-WY-A859-01A-12R-A36H-07                 48                  0
# TCGA-QH-A86X-01A-11R-A36H-07                 84                  0
# TCGA-DU-6402-01A-11R-1708-07                 27                  0
# TCGA-HT-7611-01A-11R-2403-07                 18                  0
# TCGA-DB-A4XA-01A-11R-A26U-07                 27                  0
#
# gene_id                       ENSG00000288669.1  ENSG00000288670.1  \
# TCGA-WY-A859-01A-12R-A36H-07                  0               1050
# TCGA-QH-A86X-01A-11R-A36H-07                  0               1188
# TCGA-DU-6402-01A-11R-1708-07                  0                398
# TCGA-HT-7611-01A-11R-2403-07                  0                851
# TCGA-DB-A4XA-01A-11R-A26U-07                  0                707
#
# gene_id                       ENSG00000288674.1  ENSG00000288675.1
# TCGA-WY-A859-01A-12R-A36H-07                 15                 94
# TCGA-QH-A86X-01A-11R-A36H-07                  7                 87
# TCGA-DU-6402-01A-11R-1708-07                  6                 51
# TCGA-HT-7611-01A-11R-2403-07                  4                 50
# TCGA-DB-A4XA-01A-11R-A26U-07                  6                 96
#
# [5 rows x 57582 columns]

# %% [markdown]
# Transcripts Per Million (TPM) Dataset

# %%
type_of_column = "tpm_unstranded_"

df = dataset.get_layer_by_column_type(type_of_column)
print(df.shape)

# drop last 4 rows with NaN values
df = df.dropna()
print(df.shape)

# drop columns gene_name and gene_type
df = df.drop(columns = ["gene_name", "gene_type"])
print(df.shape)

# drop genes with all zeros
df = df.drop(index=index_remove_zero)
print(df.shape)

# transpose dataframe
df = df.T

display(df.head())
dataset.set_raw_data(data_type="tpm", df=df)
# Out:
# (60664, 536)
# (60660, 536)
# (60660, 534)
# (57582, 534)
# gene_id                       ENSG00000000003.15  ENSG00000000005.6  \
# TCGA-WY-A859-01A-12R-A36H-07             34.0816             0.4358
# TCGA-QH-A86X-01A-11R-A36H-07             44.4717             0.4358
# TCGA-DU-6402-01A-11R-1708-07             63.5170             0.1585
# TCGA-HT-7611-01A-11R-2403-07             80.4729             0.3284
# TCGA-DB-A4XA-01A-11R-A26U-07             31.0150             0.2702
#
# gene_id                       ENSG00000000419.13  ENSG00000000457.14  \
# TCGA-WY-A859-01A-12R-A36H-07             66.1279              4.9375
# TCGA-QH-A86X-01A-11R-A36H-07             56.0393              5.9149
# TCGA-DU-6402-01A-11R-1708-07             69.5365              4.0278
# TCGA-HT-7611-01A-11R-2403-07             63.8477              6.9449
# TCGA-DB-A4XA-01A-11R-A26U-07             48.8297              4.3915
#
# gene_id                       ENSG00000000460.17  ENSG00000000938.13  \
# TCGA-WY-A859-01A-12R-A36H-07              1.9215              4.7708
# TCGA-QH-A86X-01A-11R-A36H-07              1.7164              7.3233
# TCGA-DU-6402-01A-11R-1708-07              3.3996             18.9023
dataset = LayerDataset(DATA_DIR, project, layer)

# %%
col_types = dataset.get_types_of_columns()
head = dataset.get_layer(n_rows=5)
ids = dataset.get_layer_by_column_type("")

print(f"Number of miRNAs: {ids.shape[0]}\nNumber of patients: {col_types.most_common()[0][1]}")
print(f"Types of columns: {col_types}")
display(head)
# Out:
# Number of miRNAs: 60664
# Number of patients: 524
# Types of columns: Counter({'unstranded_': 524, 'stranded_first_': 524, 'stranded_second_': 524, 'tpm_unstranded_': 524, 'fpkm_unstranded_': 524, 'fpkm_uq_unstranded_': 524, 'gene_id': 1, 'gene_name': 1, 'gene_type': 1})
#                    gene_name       gene_type  \
# gene_id
# ENSG00000000003.15    TSPAN6  protein_coding
# ENSG00000000005.6       TNMD  protein_coding
# ENSG00000000419.13      DPM1  protein_coding
# ENSG00000000457.14     SCYL3  protein_coding
# ENSG00000000460.17  C1orf112  protein_coding
#
#                     unstranded_TCGA-A6-6141-01A-11R-1774-07  \
# gene_id
# ENSG00000000003.15                                     4442
# ENSG00000000005.6                                        22
# ENSG00000000419.13                                     1016
# ENSG00000000457.14                                      540
# ENSG00000000460.17                                      218
#
#                     unstranded_TCGA-G4-6309-01A-21R-1839-07  \
# gene_id
# ENSG00000000003.15                                     1033
# ENSG00000000005.6                                         2
# ENSG00000000419.13                                     1500
# ENSG00000000457.14                                      329
# ENSG00000000460.17                                      399
#
#                     unstranded_TCGA-AZ-4682-01B-01R-A32Z-07  \
# gene_id
# ENSG00000000003.15                                    13510
# ENSG00000000005.6                                       326
# ENSG00000000419.13                                     6092
# ENSG00000000457.14                                      813
# ENSG00000000460.17                                      883
#
#                     unstranded_TCGA-QL-A97D-01A-12R-A41B-07  \
# gene_id
# ENSG00000000003.15                                     5351
# ENSG00000000005.6                                       181
# ENSG00000000419.13                                     3549
# ENSG00000000457.14                                      666
# ENSG00000000460.17                                      580
#
#                     unstranded_TCGA-AD-5900-01A-11R-1653-07  \
# gene_id
# ENSG00000000003.15                                     1791
# ENSG00000000005.6                                         0
# ENSG00000000419.13                                     1469
# ENSG00000000457.14                                      450
# ENSG00000000460.17                                      276
#
#                     unstranded_TCGA-AD-6963-01A-11R-1928-07  \
# gene_id
# ENSG00000000003.15                                     7331
# ENSG00000000005.6                                        10
# ENSG00000000419.13                                     6461
# ENSG00000000457.14                                      839
# ENSG00000000460.17                                      751
#
#                     unstranded_TCGA-DM-A1D4-01A-21R-A155-07  \
# gene_id
# ENSG00000000003.15                                     6596
# ENSG00000000005.6                                        36
# ENSG00000000419.13                                     3717
# ENSG00000000457.14                                      953
# ENSG00000000460.17                                      564
#
#                     unstranded_TCGA-CK-4948-01B-11R-1653-07  ...  \
# gene_id                                                      ...
# ENSG00000000003.15                                     9680  ...
# ENSG00000000005.6                                       270  ...
# ENSG00000000419.13                                     3640  ...
# ENSG00000000457.14                                      825  ...
# ENSG00000000460.17                                      719  ...
#
#                     unstranded_TCGA-DM-A1D8-01A-11R-A155-07  \
# gene_id
# ENSG00000000003.15                                    10358
# ENSG00000000005.6                                         1
# ENSG00000000419.13                                     4143
# ENSG00000000457.14                                      881
# ENSG00000000460.17                                      570
#
#                     unstranded_TCGA-DM-A1HB-01A-21R-A180-07  \
# gene_id
# ENSG00000000003.15                                     2446
# ENSG00000000005.6                                         0
# ENSG00000000419.13                                     2394
# ENSG00000000457.14                                      672
# ENSG00000000460.17                                      368
#
#                     unstranded_TCGA-DM-A28F-01A-11R-A32Y-07  \
# gene_id
# ENSG00000000003.15                                    19176
# ENSG00000000005.6                                       291
# ENSG00000000419.13                                     4622
# ENSG00000000457.14                                      951
# ENSG00000000460.17                                      858
#
#                     unstranded_TCGA-F4-6855-01A-11R-1928-07  \
# gene_id
# ENSG00000000003.15                                     5400
# ENSG00000000005.6                                        16
# ENSG00000000419.13                                     1412
# ENSG00000000457.14                                      712
# ENSG00000000460.17                                      291
#
#                     unstranded_TCGA-G4-6306-01A-11R-1774-07  \
# gene_id
# ENSG00000000003.15                                     6536
# ENSG00000000005.6                                        29
# ENSG00000000419.13                                     2653
# ENSG00000000457.14                                      202
# ENSG00000000460.17                                      115
#
#                     unstranded_TCGA-G4-6314-01A-11R-1723-07  \
# gene_id
# ENSG00000000003.15                                     8172
# ENSG00000000005.6                                        36
# ENSG00000000419.13                                     2255
# ENSG00000000457.14                                      594
# ENSG00000000460.17                                      504
#
#                     unstranded_TCGA-G4-6586-01A-11R-1774-07  \
# gene_id
# ENSG00000000003.15                                     2405
# ENSG00000000005.6                                         3
# ENSG00000000419.13                                     1462
# ENSG00000000457.14                                      439
# ENSG00000000460.17                                      288
#
#                     unstranded_TCGA-NH-A8F7-01A-11R-A41B-07  \
# gene_id
# ENSG00000000003.15                                    10413
# ENSG00000000005.6                                        91
# ENSG00000000419.13                                     3815
# ENSG00000000457.14                                      647
# ENSG00000000460.17                                      362
#
#                     unstranded_TCGA-NH-A8F7-06A-31R-A41B-07  \
# gene_id
# ENSG00000000003.15                                    15299
# ENSG00000000005.6                                        26
# ENSG00000000419.13                                     5139
# ENSG00000000457.14                                      614
# ENSG00000000460.17                                      561
#
#                     unstranded_TCGA-QG-A5Z2-01A-11R-A28H-07
# gene_id
# ENSG00000000003.15                                     3559
# ENSG00000000005.6                                        30
# ENSG00000000419.13                                     1902
# ENSG00000000457.14                                     1131
# ENSG00000000460.17                                      504
#
# [5 rows x 3146 columns]

# %% [markdown]
# Check for the presence of NaNs

# %%
t = dataset.get_layer_by_column_type('unstranded_')
t = t.drop(columns=["gene_name", "gene_type"])
print(f"Are there any NaNs?\n{t.isna().any().any()}")
# Out:
# Are there any NaNs?
# False

# %% [markdown]
# Sparsity analysis - identify and remove columns with high percentage (>95) of 0s

# %%
print("fraction of zeros in whole dataset: ", (t == 0).sum().sum() / (t.shape[0]*t.shape[1]))
zero_count = ((t == 0).sum(axis="columns") / t.shape[1])
print(zero_count.sort_values(ascending=False).head(5))
all_zero = zero_count == 1
index_remove_zero = t[all_zero].index
# Out:
# fraction of zeros in whole dataset:  0.5083016399680684
# gene_id
# ENSG00000252656.1    1.0
# ENSG00000281426.1    1.0
# ENSG00000272821.1    1.0
# ENSG00000272139.1    1.0
# ENSG00000223362.1    1.0
# dtype: float64

# %% [markdown]
# Process and save datasets

# %%
col_types = dataset.get_types_of_columns()
print("Types of columns:\n", list(col_types.keys()))
# Out:
# Types of columns:
#  ['gene_id', 'gene_name', 'gene_type', 'unstranded_', 'stranded_first_', 'stranded_second_', 'tpm_unstranded_', 'fpkm_unstranded_', 'fpkm_uq_unstranded_']

# %% [markdown]
# Raw Counts Dataset

# %%
type_of_column = "unstranded_"

df = dataset.get_layer_by_column_type(type_of_column)
print(df.shape)

# drop last 4 rows with NaN values
df = df.dropna()
print(df.shape)

# drop columns gene_name and gene_type
df = df.drop(columns = ["gene_name", "gene_type"])
print(df.shape)

# drop genes with all zeros
df = df.drop(index=index_remove_zero)
print(df.shape)

# transpose dataframe
df = df.T

display(df.head())
dataset.set_raw_data(data_type="counts", df=df)
# Out:
# (60664, 526)
# (60660, 526)
# (60660, 524)
# (57622, 524)
# gene_id                       ENSG00000000003.15  ENSG00000000005.6  \
# TCGA-A6-6141-01A-11R-1774-07                4442                 22
# TCGA-G4-6309-01A-21R-1839-07                1033                  2
# TCGA-AZ-4682-01B-01R-A32Z-07               13510                326
# TCGA-QL-A97D-01A-12R-A41B-07                5351                181
# TCGA-AD-5900-01A-11R-1653-07                1791                  0
#
# gene_id                       ENSG00000000419.13  ENSG00000000457.14  \
# TCGA-A6-6141-01A-11R-1774-07                1016                 540
# TCGA-G4-6309-01A-21R-1839-07                1500                 329
# TCGA-AZ-4682-01B-01R-A32Z-07                6092                 813
# TCGA-QL-A97D-01A-12R-A41B-07                3549                 666
# TCGA-AD-5900-01A-11R-1653-07                1469                 450
#
# gene_id                       ENSG00000000460.17  ENSG00000000938.13  \
# TCGA-A6-6141-01A-11R-1774-07                 218                 152
# TCGA-G4-6309-01A-21R-1839-07                 399                  91
# TCGA-AZ-4682-01B-01R-A32Z-07                 883                 114
# TCGA-QL-A97D-01A-12R-A41B-07                 580                 131
# TCGA-AD-5900-01A-11R-1653-07                 276                 426
#
# gene_id                       ENSG00000000971.16  ENSG00000001036.14  \
# TCGA-A6-6141-01A-11R-1774-07                 383                2108
# TCGA-G4-6309-01A-21R-1839-07                 278                4419
# TCGA-AZ-4682-01B-01R-A32Z-07                 594                6515
# TCGA-QL-A97D-01A-12R-A41B-07                 494                1520
# TCGA-AD-5900-01A-11R-1653-07                 956                1914
#
# gene_id                       ENSG00000001084.13  ENSG00000001167.14  ...  \
# TCGA-A6-6141-01A-11R-1774-07                1335                 896  ...
# TCGA-G4-6309-01A-21R-1839-07                1592                1156  ...
# TCGA-AZ-4682-01B-01R-A32Z-07                3346                1739  ...
# TCGA-QL-A97D-01A-12R-A41B-07                1859                1888  ...
# TCGA-AD-5900-01A-11R-1653-07                1728                 968  ...
#
# gene_id                       ENSG00000288658.1  ENSG00000288659.1  \
# TCGA-A6-6141-01A-11R-1774-07                  7                  0
# TCGA-G4-6309-01A-21R-1839-07                  1                  0
# TCGA-AZ-4682-01B-01R-A32Z-07                  4                  0
# TCGA-QL-A97D-01A-12R-A41B-07                  1                  0
# TCGA-AD-5900-01A-11R-1653-07                  6                  0
#
# gene_id                       ENSG00000288660.1  ENSG00000288662.1  \
# TCGA-A6-6141-01A-11R-1774-07                  2                  0
# TCGA-G4-6309-01A-21R-1839-07                  1                  0
# TCGA-AZ-4682-01B-01R-A32Z-07                  4                  0
# TCGA-QL-A97D-01A-12R-A41B-07                  2                  0
# TCGA-AD-5900-01A-11R-1653-07                  0                  0
#
# gene_id                       ENSG00000288663.1  ENSG00000288667.1  \
# TCGA-A6-6141-01A-11R-1774-07                 15                  0
# TCGA-G4-6309-01A-21R-1839-07                 18                  0
# TCGA-AZ-4682-01B-01R-A32Z-07                 20                  0
# TCGA-QL-A97D-01A-12R-A41B-07                 46                  0
# TCGA-AD-5900-01A-11R-1653-07                  9                  0
#
# gene_id                       ENSG00000288669.1  ENSG00000288670.1  \
# TCGA-A6-6141-01A-11R-1774-07                  0                 89
# TCGA-G4-6309-01A-21R-1839-07                  0                107
# TCGA-AZ-4682-01B-01R-A32Z-07                  0                206
# TCGA-QL-A97D-01A-12R-A41B-07                  0                240
# TCGA-AD-5900-01A-11R-1653-07                  0                169
#
# gene_id                       ENSG00000288674.1  ENSG00000288675.1
# TCGA-A6-6141-01A-11R-1774-07                  8                 18
# TCGA-G4-6309-01A-21R-1839-07                  1                 13
# TCGA-AZ-4682-01B-01R-A32Z-07                  6                 16
# TCGA-QL-A97D-01A-12R-A41B-07                  4                 12
# TCGA-AD-5900-01A-11R-1653-07                  4                 14
#
# [5 rows x 57622 columns]

# %% [markdown]
# Transcripts Per Million (TPM) Dataset

# %%
type_of_column = "tpm_unstranded_"

df = dataset.get_layer_by_column_type(type_of_column)
print(df.shape)

# drop last 4 rows with NaN values
df = df.dropna()
print(df.shape)

# drop columns gene_name and gene_type
df = df.drop(columns = ["gene_name", "gene_type"])
print(df.shape)

# drop genes with all zeros
df = df.drop(index=index_remove_zero)
print(df.shape)

# transpose dataframe
df = df.T

display(df.head())
dataset.set_raw_data(data_type="tpm", df=df)
# Out:
# (60664, 526)
# (60660, 526)
# (60660, 524)
# (57622, 524)
# gene_id                       ENSG00000000003.15  ENSG00000000005.6  \
# TCGA-A6-6141-01A-11R-1774-07             77.1112             1.1737
# TCGA-G4-6309-01A-21R-1839-07             21.2720             0.1266
# TCGA-AZ-4682-01B-01R-A32Z-07            165.5622            12.2775
# TCGA-QL-A97D-01A-12R-A41B-07             79.2385             8.2370
# TCGA-AD-5900-01A-11R-1653-07             34.0663             0.0000
#
# gene_id                       ENSG00000000419.13  ENSG00000000457.14  \
# TCGA-A6-6141-01A-11R-1774-07             66.2824              6.1777
# TCGA-G4-6309-01A-21R-1839-07            116.0821              4.4648
# TCGA-AZ-4682-01B-01R-A32Z-07            280.5638              6.5659
# TCGA-QL-A97D-01A-12R-A41B-07            197.5027              6.4994
# TCGA-AD-5900-01A-11R-1653-07            105.0067              5.6408
#
# gene_id                       ENSG00000000460.17  ENSG00000000938.13  \
# TCGA-A6-6141-01A-11R-1774-07              2.8754              3.5390
# TCGA-G4-6309-01A-21R-1839-07              6.2428              2.5133
